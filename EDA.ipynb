# %% [markdown]
# Inicializamos librerias y cargamos los CSV

# %%
# Cargamos librerias y cambiamos algunos parametros que me permiten sacar mas informacin en cada celda

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" # Este muestra todas las salidas de la celda y no solo la ultima 
import pandas as pd
pd.set_option('display.max_rows', 300) # este cambia la cantidad de filas de los DF de pandas que se visualiza a 300 
import numpy as np
from IPython.display import display # este me permite mostrar contenido extra
from rapidfuzz import process, fuzz, utils #Para limpiar un poco la lista de actores


# Cargamos los datos provistos 
disney = pd.read_csv("./Datasets/disney_plus_titles.csv")
amazon = pd.read_csv("./Datasets/amazon_prime_titles.csv")
hulu = pd.read_csv("./Datasets/hulu_titles.csv")
netflix = pd.read_json("./Datasets/netflix_titles.json")

# %% [markdown]
# Visualizamos los datasets para saber con que datos contamos

# %%
# Visualizamos informacion basica de los datos

display(disney.info())
display(amazon.info())
display(hulu.info())
display(netflix.info())

# Visualizamos cuantas variables unicas (no repetidas) tiene cada dataset
disney.nunique()
amazon.nunique()
hulu.nunique()
netflix.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1450 non-null   object
#  1   type          1450 non-null   object
#  2   title         1450 non-null   object
#  3   director      977 non-null    object
#  4   cast          1260 non-null   object
#  5   country       1231 non-null   object
#  6   date_added    1447 non-null   object
#  7   release_year  1450 non-null   int64
#  8   rating        1447 non-null   object
#  9   duration      1450 non-null   object
#  10  listed_in     1450 non-null   object
#  11  description   1450 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 136.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7586 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 906.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3073 entries, 0 to 3072
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       3073 non-null   object
#  1   type          3073 non-null   object
#  2   title         3073 non-null   object
#  3   director      3 non-null      object
#  4   cast          0 non-null      float64
#  5   country       1620 non-null   object
#  6   date_added    3045 non-null   object
#  7   release_year  3073 non-null   int64
#  8   rating        2553 non-null   object
#  9   duration      2594 non-null   object
#  10  listed_in     3073 non-null   object
#  11  description   3069 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 288.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.5+ KB
# None
# show_id         1450
# type               2
# title           1450
# director         609
# cast            1193
# country           89
# date_added       167
# release_year      90
# rating             9
# duration         158
# listed_in        329
# description     1448
# dtype: int64
# show_id         9668
# type               2
# title           9668
# director        5774
# cast            7927
# country           86
# date_added        84
# release_year     100
# rating            24
# duration         219
# listed_in        518
# description     9414
# dtype: int64
# show_id         3073
# type               2
# title           3073
# director           3
# cast               0
# country          150
# date_added      1115
# release_year      72
# rating            88
# duration         135
# listed_in        442
# description     3057
# dtype: int64
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %% [markdown]
# De la informacion anterior podemos ver que hay duplicados en la descripcion, puede
# Buscamos duplicados internos en los datasets, despues entre los distintos datasets

# %%
# Removemos la fila id, pues no tenia información para el contexto de todos los datasets juntos.

disney.drop('show_id', axis = 1, inplace=True)
amazon.drop('show_id', inplace=True, axis = 1)
hulu.drop('show_id', inplace=True, axis = 1)
netflix.drop('show_id', inplace=True, axis = 1)

# Removemos duplicados de cada dataset, ahora si seran duplicados aunque tengan otro 'Show_id'
disney.drop_duplicates(inplace=True)
amazon.drop_duplicates(inplace=True)
hulu.drop_duplicates(inplace=True)
netflix.drop_duplicates(inplace=True)

# %%
# Vemos los cambios que logramos en los datasets
display(disney.info())
display(amazon.info())
display(hulu.info())
display(netflix.info())

disney.nunique()
amazon.nunique()
hulu.nunique()
netflix.nunique()
# Aqui vemos que no tenian duplicados los datasets

# vemos filas de los datasets
disney.head(30)
amazon.head(30)
hulu.head(30)
netflix.head(30)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1450 entries, 0 to 1449
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          1450 non-null   object
#  1   title         1450 non-null   object
#  2   director      977 non-null    object
#  3   cast          1260 non-null   object
#  4   country       1231 non-null   object
#  5   date_added    1447 non-null   object
#  6   release_year  1450 non-null   int64
#  7   rating        1447 non-null   object
#  8   duration      1450 non-null   object
#  9   listed_in     1450 non-null   object
#  10  description   1450 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 135.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9668 entries, 0 to 9667
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          9668 non-null   object
#  1   title         9668 non-null   object
#  2   director      7586 non-null   object
#  3   cast          8435 non-null   object
#  4   country       672 non-null    object
#  5   date_added    155 non-null    object
#  6   release_year  9668 non-null   int64
#  7   rating        9331 non-null   object
#  8   duration      9668 non-null   object
#  9   listed_in     9668 non-null   object
#  10  description   9668 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 906.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3073 entries, 0 to 3072
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          3073 non-null   object
#  1   title         3073 non-null   object
#  2   director      3 non-null      object
#  3   cast          0 non-null      float64
#  4   country       1620 non-null   object
#  5   date_added    3045 non-null   object
#  6   release_year  3073 non-null   int64
#  7   rating        2553 non-null   object
#  8   duration      2594 non-null   object
#  9   listed_in     3073 non-null   object
#  10  description   3069 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 288.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8807 entries, 0 to 8806
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      6173 non-null   object
#  3   cast          7982 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8797 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
#  10  description   8807 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 825.7+ KB
# None
# type               2
# title           1450
# director         609
# cast            1193
# country           89
# date_added       167
# release_year      90
# rating             9
# duration         158
# listed_in        329
# description     1448
# dtype: int64
# type               2
# title           9668
# director        5774
# cast            7927
# country           86
# date_added        84
# release_year     100
# rating            24
# duration         219
# listed_in        518
# description     9414
# dtype: int64
# type               2
# title           3073
# director           3
# cast               0
# country          150
# date_added      1115
# release_year      72
# rating            88
# duration         135
# listed_in        442
# description     3057
# dtype: int64
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64
#        type                                             title  \
# 0     Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1     Movie                            Ernest Saves Christmas
# 2     Movie                      Ice Age: A Mammoth Christmas
# 3     Movie                        The Queen Family Singalong
# 4   TV Show                             The Beatles: Get Back
# 5     Movie                                 Becoming Cousteau
# 6   TV Show                                           Hawkeye
# 7   TV Show                            Port Protection Alaska
# 8   TV Show                         Secrets of the Zoo: Tampa
# 9     Movie             A Muppets Christmas: Letters To Santa
# 10    Movie           Adventure Thru the Walt Disney Archives
# 11    Movie                                Puppy for Hanukkah
# 12    Movie                                   The Pixar Story
# 13  TV Show                             Dr. Oakley, Yukon Vet
# 14    Movie                             America the Beautiful
# 15    Movie                                           Baymax!
# 16    Movie                                      Ciao Alberto
# 17  TV Show                                Disney Fancy Nancy
# 18  TV Show                                Disney Intertwined
# 19    Movie                                         Enchanted
# 20    Movie                                             Feast
# 21    Movie                                      Frozen Fever
# 22    Movie                                      Get a Horse!
# 23    Movie                             Home Sweet Home Alone
# 24    Movie                                     Jungle Cruise
# 25    Movie                    Limitless with Chris Hemsworth
# 26    Movie          Marvel Studios’ 2021 Disney+ Day Special
# 27    Movie                                    Obi-Wan Kenobi
# 28  TV Show                                     Olaf Presents
# 29    Movie                                          Paperman
#
#                              director  \
# 0   Alonso Ramirez Ramos, Dave Wasson
# 1                         John Cherry
# 2                        Karen Disher
# 3                     Hamish Hamilton
# 4                                 NaN
# 5                          Liz Garbus
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 9                    Kirk R. Thatcher
# 10                         John Gleim
# 11                                NaN
# 12                      Leslie Iwerks
# 13                                NaN
# 14                                NaN
# 15                                NaN
# 16                     McKenna Harris
# 17                                NaN
# 18                                NaN
# 19                         Kevin Lima
# 20                    Patrick Osborne
# 21           Chris Buck, Jennifer Lee
# 22                   Lauren MacMullan
# 23                          Dan Mazer
# 24                 Jaume Collet-Serra
# 25                                NaN
# 26                                NaN
# 27                                NaN
# 28                                NaN
# 29                         John Kahrs
#
#                                                  cast                country  \
# 0   Chris Diamantopoulos, Tony Anselmo, Tress MacN...                    NaN
# 1            Jim Varney, Noelle Parker, Douglas Seale                    NaN
# 2   Raymond Albert Romano, John Leguizamo, Denis L...          United States
# 3   Darren Criss, Adam Lambert, Derek Hough, Alexa...                    NaN
# 4   John Lennon, Paul McCartney, George Harrison, ...                    NaN
# 5               Jacques Yves Cousteau, Vincent Cassel          United States
# 6   Jeremy Renner, Hailee Steinfeld, Vera Farmiga,...                    NaN
# 7                    Docuseries, Reality, Survival
# 8             Animals & Nature, Docuseries, Family
# 9                          Comedy, Family, Musical
# 10                                     Documentary
# 11                           Comedy, Family, Music
# 12                             Documentary, Family
# 13  Action-Adventure, Animals & Nature, Docuseries
# 14                                Animals & Nature
# 15                                       Animation
# 16                       Animation, Comedy, Family
# 17                                 Animation, Kids
# 18                    Comedy, Coming of Age, Drama
# 19                         Comedy, Family, Fantasy
# 20                        Animation, Comedy, Drama
# 21                      Animation, Family, Fantasy
# 22             Action-Adventure, Animation, Comedy
# 23                                  Comedy, Family
# 24                Action-Adventure, Comedy, Family
# 25                                       Lifestyle
# 26                                          Movies
# 27               Action-Adventure, Science Fiction
# 28                               Animation, Family
# 29                       Animation, Comedy, Family
#
#                                           description
# 0    Join Mickey and the gang as they duck the halls!
# 1   Santa Claus passes his magic bag to a new St. ...
# 2           Sid the Sloth is on Santa's naughty list.
# 3                This is real life, not just fantasy!
# 4   A three-part documentary from Peter Jackson ca...
# 5   An inside look at the legendary life of advent...
# 6   Clint Barton/Hawkeye must team up with skilled...
# 7   Residents of Port Protection must combat volat...
# 8   A day in the life at ZooTampa is anything but ...
# 9   Celebrate the holiday season with all your fav...
# 10  Explore the treasures and rich history of the ...
# 11  Check out Daveed Digg's official music video "...
# 12  A groundbreaking company forever changes the f...
# 13  Meet Dr. Michelle Oakley, vet to pretty much e...
# 14  Epic, grand portrait of the land across four r...
# 15        “Baymax!” premieres on Disney+ summer 2022.
# 16  Fun-loving sea monster Alberto whole-heartedly...
# 17               Nancy makes every day extraordinary!
# 18  Allegra is ready to change the past in order t...
# 19  An animated princess winds up in the real worl...
# 20  One man's love life seen through the eyes of h...
# 21  Elsa wants to give Anna the best birthday part...
# 22  Mickey and friends hitch a ride on a musical h...
# 23  Alone for the holidays, Max Mercer will do wha...
# 24  Dr. Lily Houghton & skipper Frank Wolff team u...
# 25  "Limitless with Chris Hemsworth" is coming to ...
# 26  Marvel Studios’ Disney+ Day Special explores t...
# 27  A behind the scenes look of the "Obi-Wan Kenob...
# 28  Olaf goes from snowman to showman for his uniq...
# 29    A young man strives to find girl of his dreams.
#        type                              title                     director  \
# 0     Movie                The Grand Seduction                 Don McKellar
# 1     Movie               Take Care Good Night                 Girish Joshi
# 2     Movie               Secrets of Deception                  Josh Webber
# 3     Movie                 Pink: Staying True               Sonia Anderson
# 4     Movie                      Monster Maker                 Giles Foster
# 5     Movie              Living With Dinosaurs                 Paul Weiland
# 6     Movie                          Hired Gun                  Fran Strine
# 7     Movie                       Grease Live!  Thomas Kail, Alex Rudzinski
# 8     Movie                    Global Meltdown                Daniel Gilboy
# 9     Movie                     David's Mother        Robert Allan Ackerman
# 10    Movie                     Forest Fairies               Justin G. Dyck
# 11    Movie                          Take Care                 Liz Tuccillo
# 12    Movie           The Night Eats The World             Dominique Rocher
# 13    Movie                         Resilencia                Jep Barcelona
# 14    Movie  Elon Musk: The Real Life Iron Man               Sonia Anderson
# 15    Movie                         Summer '03                Becca Gleason
# 16    Movie                           Zoombies                 Glenn Miller
# 17  TV Show                         Zoo Babies                          NaN
# 18  TV Show      Zoë Coombs Marr: Bossy Bottom                          NaN
# 19    Movie                                Zoe                Drake Doremus
# 20  TV Show                         Zoboomafoo                          NaN
# 21  TV Show          Zo Zo Zombie: Mini-Series                          NaN
# 22    Movie                       Zis Boom Bah                 William Nigh
# 23  TV Show                       ZeroZeroZero                          NaN
# 24    Movie                           Zandalee                Sam Pillsbury
# 25    Movie             Zambezi: Force of Life           Dr. Rudolf Lammers
# 26  TV Show                 Zahara: The Return                          NaN
# 27  TV Show     Z: The Beginning of Everything                          NaN
# 28  TV Show                    Yu-Gi-Oh! Zexal                          NaN
# 29  TV Show                    Yu-Gi-Oh! ARC-V                          NaN
#
#                                                  cast         country  \
# 0      Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1    Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2   Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3   Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4   Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
# 5   Gregory Chisholm, Juliet Stevenson, Brian Hens...  United Kingdom
# 6   Alice Cooper, Liberty DeVitto, Ray Parker Jr.,...   United States
# 7   Julianne Hough, Aaron Tveit, Vanessa Hudgens, ...   United States
# 8   Michael Paré, Leanne Khol Young, Patrick J. Ma...          Canada
# 9     Kirstie Alley, Sam Waterston, Stockard Channing   United States
# 10  Emily Wilder, Adrian Cowan, Gary Mckenzie, Jer...          Canada
# 11            Leslie Bibb, Kevin Curtis, Nadia Dajani   United States
# 12  Anders Danielsen Lie, Golshifteh Farahani, Den...          France
# 13  Rafinha Alcantara, Marc-André Ter Stegen, Serg...           Spain
# 14  Elon Musk, Per Wimmer, Julie Anderson-Ankenbra...  United Kingdom
# 15  Joey King, Jack Kilmer, Andrea Savage, Paul Sc...   United States
# 16         Marcus Anderson, Kaiwi Lyman, Andrew Asper             NaN
# 17                         Narrator - Gillian Barlett             NaN
# 18                                    Zoë Coombs Marr             NaN
# 19  Ewan McGregor, Léa Seydoux, Theo James, Mirand...             NaN
# 20                                                NaN             NaN
# 21  Alex Cazares, Ben Diskin, Cristina Vee, Erika ...             NaN
# 22                            Grace Hayes, Mary Healy             NaN
# 23  ANDREA RISEBOROUGH, HAROLD TORRES, CLAUDIA PIN...           Italy
# 24  Nicolas Cage, Judge Reinhold, Erika Anderson, ...             NaN
# 25                                                NaN             NaN
# 26  Natasha Heschélle, Curtis Morgan, Hannah Scott...             NaN
# 27                    Christina Ricci
# , David Hoflin   United States
# 28  Eli Jay, Marc Thompson, Sean Schemmel, Eileen ...             NaN
# 29                    Michael Liscio Jr., Emily Bauer             NaN
#
#         date_added  release_year rating   duration  \
# 0   March 30, 2021          2014    NaN    113 min
# 1   March 30, 2021          2018    13+    110 min
# 2   March 30, 2021          2017    NaN     74 min
# 3   March 30, 2021          2014    NaN     69 min
# 4   March 30, 2021          1989    NaN     45 min
# 5   March 30, 2021          1989    NaN     52 min
# 6   March 30, 2021          2017    NaN     98 min
# 7   March 30, 2021          2016    NaN    131 min
# 8   March 30, 2021          2017    NaN     87 min
# 9    April 1, 2021          1994    NaN     92 min
# 10   April 4, 2021          2016    NaN     88 min
# 11  April 10, 2021          2014    NaN     93 min
# 12  April 17, 2021          2018    NaN     94 min
# 13  April 24, 2021          2020    NaN     46 min
# 14     May 2, 2021          2018    NaN     74 min
# 15    June 3, 2021          2019    NaN     96 min
# 16             NaN          2016    13+     87 min
# 17             NaN          2008    ALL   1 Season
# 18             NaN          2020    18+   1 Season
# 19             NaN          2018      R    104 min
# 20             NaN          2001   TV-Y   1 Season
# 21             NaN          2020  TV-Y7   1 Season
# 22             NaN          1941     NR     62 min
# 23             NaN          2020    18+   1 Season
# 24             NaN          1991      R     94 min
# 25             NaN          2005    ALL     50 min
# 26             NaN          2020    16+   1 Season
# 27             NaN          2017    18+   1 Season
# 28             NaN          2015  TV-Y7  3 Seasons
# 29             NaN          2018  TV-Y7  3 Seasons
#
#                                           listed_in  \
# 0                                     Comedy, Drama
# 1                              Drama, International
# 2                           Action, Drama, Suspense
# 3                                       Documentary
# 4                                    Drama, Fantasy
# 5                                     Fantasy, Kids
# 6                     Documentary, Special Interest
# 7                                            Comedy
# 8                 Action, Science Fiction, Suspense
# 9                                             Drama
# 10                                  Adventure, Kids
# 11                                           Comedy
# 12                                 Horror, Suspense
# 13                              Documentary, Sports
# 14                                      Documentary
# 15                                    Comedy, Drama
# 16                          Horror, Science Fiction
# 17                           Kids, Special Interest
# 18                    Comedy, Talk Show and Variety
# 19                                  Science Fiction
# 20                                             Kids
# 21                            Action, Anime, Comedy
# 22  Arts, Entertainment, and Culture, Comedy, Drama
# 23                                         TV Shows
# 24                                            Drama
# 25                                      Documentary
# 26                                         TV Shows
# 27                                    Comedy, Drama
# 28                        Animation, Anime, Fantasy
# 29                     Action, Adventure, Animation
#
#                                           description
# 0   A small fishing village must procure a local d...
# 1   A Metro Family decides to fight a Cyber Crimin...
# 2   After a man discovers his wife is cheating on ...
# 3   Pink breaks the mold once again, bringing her ...
# 4   Teenage Matt Banting wants to work with a famo...
# 5   The story unfolds in a an English seaside town...
# 6   They are the "First Call, A-list" musicians, j...
# 7   This honest, uncompromising comedy chronicles ...
# 8   A helicopter pilot and an environmental scient...
# 9   Sally Goodson is a devoted mother to her autis...
# 10  Amanda stumbles upon a hidden village of fairi...
# 11  When a car crash leaves Frannie immobilized, s...
# 12  After waking up in an apartment the night afte...
# 13  The documentary follows the midfielder’s every...
# 14  Discover the meteoric rise of Elon Musk, the m...
# 15  Summer '03 is the hilarious story of 16-year-o...
# 16  When a strange virus quickly spreads through a...
# 17  A heart warming and inspiring series that welc...
# 18  Zoë Coombs Marr has been on hiatus. Sort of. F...
# 19  ZOE tells a tale of forbidden love between an ...
# 20  Chris and Martin Kratt bring their enthusiasm ...
# 21  Zo Zo Zombie is our undead hero who, with his ...
# 22  "Hey, kids, let's get together and put on a sh...
# 23  ZeroZeroZero series follows the journey of a c...
# 24  Zandalee has grown bored with her poet-turned-...
# 25  The Zambezi river is the fourth-longest river ...
# 26  The story explores the history of slavery and ...
# 27  "Z: The Beginning of Everything" tells the sto...
# 28  It's time to feel the flow as Yu-Gi-Oh! Zexal ...
# 29  Get set to swing into action as Yu-Gi-Oh! ARC-...
#        type                                              title director  cast  \
# 0     Movie                     Ricky Velez: Here's Everything      NaN   NaN
# 1     Movie                                       Silent Night      NaN   NaN
# 2     Movie                                       The Marksman      NaN   NaN
# 3     Movie                                               Gaia      NaN   NaN
# 4     Movie                                           Settlers      NaN   NaN
# 5   TV Show                      The Halloween Candy Magic Pet      NaN   NaN
# 6     Movie                                 The Evil Next Door      NaN   NaN
# 7   TV Show                             The Next Thing You Eat      NaN   NaN
# 8   TV Show                                             Queens      NaN   NaN
# 9   TV Show                                   The Bachelorette      NaN   NaN
# 10  TV Show  The Real Queens of Hip-Hop: The Women Who Chan...      NaN   NaN
# 11    Movie                                        Dream Horse      NaN   NaN
# 12    Movie  Out of the Shadows: The Man Behind the Steele ...      NaN   NaN
# 13  TV Show                                          Wakefield      NaN   NaN
# 14  TV Show                                    Home Sweet Home      NaN   NaN
# 15    Movie  Showtime Championship Boxing: Lopez vs. Salido...      NaN   NaN
# 16  TV Show    Showtime Championship Boxing: Wilder vs. Molina      NaN   NaN
# 17  TV Show                          America's Book of Secrets      NaN   NaN
# 18  TV Show                                  Beyond Oak Island      NaN   NaN
# 19  TV Show                             Beyond Scared Straight      NaN   NaN
# 20    Movie                                  Cheer Camp Killer      NaN   NaN
# 21  TV Show                                           Hoarders      NaN   NaN
# 22  TV Show                              Little Women: Atlanta      NaN   NaN
# 23  TV Show                                  Marrying Millions      NaN   NaN
# 24  TV Show                                         Nightwatch      NaN   NaN
# 25  TV Show                                  Seven Year Switch      NaN   NaN
# 26    Movie                                        Sleepwalker      NaN   NaN
# 27  TV Show                                       Swamp People      NaN   NaN
# 28  TV Show                                           Unsolved      NaN   NaN
# 29  TV Show                                     Acapulco Shore      NaN   NaN
#
#           country        date_added  release_year rating   duration  \
# 0             NaN  October 24, 2021          2021  TV-MA        NaN
# 1             NaN  October 23, 2021          2020    NaN     94 min
# 2             NaN  October 23, 2021          2021  PG-13    108 min
# 3             NaN  October 22, 2021          2021      R     97 min
# 4             NaN  October 22, 2021          2021    NaN    104 min
# 5             NaN  October 22, 2021          2021    NaN   1 Season
# 6             NaN  October 21, 2021          2020    NaN     88 min
# 7             NaN  October 21, 2021          2021    NaN   1 Season
# 8             NaN  October 20, 2021          2021  TV-14   1 Season
# 9   United States  October 20, 2021          2003  TV-14  3 Seasons
# 10            NaN  October 19, 2021          2021    NaN   1 Season
# 11            NaN  October 18, 2021          2020     PG    113 min
# 12            NaN  October 18, 2021          2021    NaN        NaN
# 13            NaN  October 18, 2021          2021    NaN   1 Season
# 14            NaN  October 16, 2021          2021  TV-PG   1 Season
# 15            NaN  October 16, 2021          2011    NaN        NaN
# 16            NaN  October 16, 2021          2015  TV-14   1 Season
# 17  United States  October 15, 2021          2012  TV-14   1 Season
# 18            NaN  October 15, 2021          2020  TV-PG   1 Season
# 2   TV Show                                          Ganglands
# 3   TV Show                              Jailbirds New Orleans
# 4   TV Show                                       Kota Factory
# 5   TV Show                                      Midnight Mass
# 6     Movie                   My Little Pony: A New Generation
# 7     Movie                                            Sankofa
# 8   TV Show                      The Great British Baking Show
# 9     Movie                                       The Starling
# 10  TV Show                Vendetta: Truth, Lies and The Mafia
# 11  TV Show                                   Bangkok Breaking
# 12    Movie                                       Je Suis Karl
# 13    Movie                   Confessions of an Invisible Girl
# 14  TV Show                    Crime Stories: India Detectives
# 15  TV Show                                  Dear White People
# 16    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 17  TV Show                                    Falsa identidad
# 18    Movie                                          Intrusion
# 19  TV Show                                             Jaguar
# 20  TV Show    Monsters Inside: The 24 Faces of Billy Milligan
# 21  TV Show                             Resurrection: Ertugrul
# 22    Movie                                    Avvai Shanmughi
# 23    Movie       Go! Go! Cory Carson: Chrissy Takes the Wheel
# 24    Movie                                              Jeans
# 25  TV Show                               Love on the Spectrum
# 26    Movie                                     Minsara Kanavu
# 27    Movie                                          Grown Ups
# 28    Movie                                         Dark Skies
# 29    Movie                                           Paranoia
#
#                                          director  \
# 0                                 Kirsten Johnson
# 1                                            None
# 2                                 Julien Leclercq
# 3                                            None
# 4                                            None
# 5                                   Mike Flanagan
# 6                   Robert Cullen, José Luis Ucha
# 7                                    Haile Gerima
# 8                                 Andy Devonshire
# 9                                  Theodore Melfi
# 10                                           None
# 11                              Kongkiat Komesiri
# 12                            Christian Schwochow
# 13                                  Bruno Garotti
# 14                                           None
# 15                                           None
# 16  Pedro de Echave García, Pablo Azorín Williams
# 17                                           None
# 18                                     Adam Salky
# 19                                           None
# 20                                Olivier Megaton
# 21                                           None
# 22                                 K.S. Ravikumar
# 23                        Alex Woo, Stanley Moore
# 24                                     S. Shankar
# 25                                           None
# 26                                    Rajiv Menon
# 27                                   Dennis Dugan
# 28                                  Scott Stewart
# 29                                 Robert Luketic
#
#                                                  cast  \
# 0                                                None
# 1   Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2   Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                None
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5   Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 10                                               None
# 11  Sukollawat Kanarot, Sushar Manaying, Pavarit M...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 13  Klara Castanho, Lucca Picon, Júlia Gomes, Marc...
# 14                                               None
# 15  Logan Browning, Brandon P. Bell, DeRon Horton,...
# 16                                               None
# 17  Luis Ernesto Franco, Camila Sodi, Sergio Goyri...
# 18  Freida Pinto, Logan Marshall-Green, Robert Joh...
# 19  Blanca Suárez, Iván Marcos, Óscar Casas, Adriá...
# 20                                               None
# 21  Engin Altan Düzyatan, Serdar Gökhan, Hülya Dar...
# 22  Kamal Hassan, Meena, Gemini Ganesan, Heera Raj...
# 23  Maisie Benson, Paul Killam, Kerry Gudjohnsen, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# 14       British TV Shows, Crime TV Shows, Docuseries
# 15                             TV Comedies, TV Dramas
# 16                Documentaries, International Movies
# 17  Crime TV Shows, Spanish-Language TV Shows, TV ...
# 18                                          Thrillers
# 19  International TV Shows, Spanish-Language TV Sh...
# 20  Crime TV Shows, Docuseries, International TV S...
# 21  International TV Shows, TV Action & Adventure,...
# 22                     Comedies, International Movies
# 23                           Children & Family Movies
# 24    Comedies, International Movies, Romantic Movies
# 25     Docuseries, International TV Shows, Reality TV
# 26   Comedies, International Movies, Music & Musicals
# 27                                           Comedies
# 28                    Horror Movies, Sci-Fi & Fantasy
# 29                                          Thrillers
#
#                                           description
# 0   As her father nears the end of his life, filmm...
# 1   After crossing paths at a party, a Cape Town t...
# 2   To protect his family from a powerful drug lor...
# 3   Feuds, flirtations and toilet talk go down amo...
# 4   In a city of coaching centers known to train I...
# 5   The arrival of a charismatic young priest brin...
# 6   Equestria's divided. But a bright-eyed hero be...
# 7   On a photo shoot in Ghana, an American model s...
# 8   A talented batch of amateur bakers face off in...
# 9   A woman adjusting to life after a loss contend...
# 10  Sicily boasts a bold "Anti-Mafia" coalition. B...
# 11  Struggling to earn a living in Bangkok, a man ...
# 12  After most of her family is murdered in a terr...
# 13  When the clever but socially-awkward Tetê join...
# 14  Cameras following Bengaluru police on the job ...
# 15  Students of color navigate the daily slights a...
# 16  Declassified documents reveal the post-WWII li...
# 17  Strangers Diego and Isabel flee their home in ...
# 18  After a deadly home invasion at a couple’s new...
# 19  In the 1960s, a Holocaust survivor joins a gro...
# 20  In the late 1970s, an accused serial rapist cl...
# 21  When a good deed unwittingly endangers his cla...
# 22  Newly divorced and denied visitation rights wi...
# 23  From arcade games to sled days and hiccup cure...
# 24  When the father of the man she loves insists t...
# 25  Finding love can be hard for anyone. For young...
# 26  A tangled love triangle ensues when a man fall...
# 27  Mourning the loss of their beloved junior high...
# 28  A family’s idyllic suburban life shatters when...
# 29  Blackmailed by his company's CEO, a low-level ...

# %% [markdown]
# Concatenamos los datasets

# %%
disney['platform'] = "Disney"
amazon['platform']= "Amazon"
hulu['platform'] = "Hulu"
netflix['platform'] = "Netflix"

df = pd.concat([disney, amazon, hulu, netflix], ignore_index=True)

#No necesitamos mantener otra columna indice
df = df.reset_index(drop=True)

#Revisamos como queda la concatenacion
df.info()
df.nunique()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22998 entries, 0 to 22997
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          22998 non-null  object
#  1   title         22998 non-null  object
#  2   director      14739 non-null  object
#  3   cast          17677 non-null  object
#  4   country       11499 non-null  object
#  5   date_added    13444 non-null  object
#  6   release_year  22998 non-null  int64
#  7   rating        22134 non-null  object
#  8   duration      22516 non-null  object
#  9   listed_in     22998 non-null  object
#  10  description   22994 non-null  object
#  11  platform      22998 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 2.1+ MB
# type                2
# title           22115
# director        10106
# cast            16748
# country           886
# date_added       2058
# release_year      101
# rating            105
# duration          253
# listed_in        1687
# description     22670
# platform            4
# dtype: int64
#       type                                             title  \
# 0    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1    Movie                            Ernest Saves Christmas
# 2    Movie                      Ice Age: A Mammoth Christmas
# 3    Movie                        The Queen Family Singalong
# 4  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# 3  Darren Criss, Adam Lambert, Derek Hough, Alexa...            NaN
# 4  John Lennon, Paul McCartney, George Harrison, ...            NaN
#
#           date_added  release_year rating  duration  \
# 0  November 26, 2021          2016   TV-G    23 min
# 1  November 26, 2021          1988     PG    91 min
# 2  November 26, 2021          2011   TV-G    23 min
# 3  November 26, 2021          2021  TV-PG    41 min
# 4  November 25, 2021          2021    NaN  1 Season
#
#                        listed_in  \
# 0              Animation, Family
# 1                         Comedy
# 2      Animation, Comedy, Family
# 3                        Musical
# 4  Docuseries, Historical, Music
#
#                                          description platform
# 0   Join Mickey and the gang as they duck the halls!   Disney
# 1  Santa Claus passes his magic bag to a new St. ...   Disney
# 2          Sid the Sloth is on Santa's naughty list.   Disney
# 3               This is real life, not just fantasy!   Disney
# 4  A three-part documentary from Peter Jackson ca...   Disney

# %%
# Encontramos que algunass filas tienen la duracion en la columna de rating, buscamos corregir

mask = df['rating'].str.find('min')>0 # Creamos una mascara en la que es verdadero si encuentra la palabra min en la columna rating

df.loc[mask, 'duration'] = df[df['rating'].str.find('min')>0].rating # Usamos la mascara pasar en esas columnas la informacion de rating a duracion
df.loc[mask, 'rating'] = pd.NA # En esas mismas filas, un cambio para remover la información de rating que debia estar en duración

# Usamos el mismo procedimiento pero para las que contengan season, tambien esta seasons, pero si contiene season, contiene Seasons

mask = df['rating'].str.find('Season')>0
df.loc[mask, 'duration'] = df[df['rating'].str.find('min')>0].rating # Usamos la mascara pasar en esas columnas la informacion de rating a duracion
df.loc[mask, 'rating'] = pd.NA


# Verificamos con un ejemplo que se debio corregir
df[df['title'] == 'Loro']
# Out:
#         type title director cast country         date_added  release_year  \
# 13067  Movie  Loro      NaN  NaN   Italy  December 20, 2019          2018
#
#       rating duration             listed_in  \
# 13067   <NA>  157 min  Drama, International
#
#                                              description platform
# 13067  Sex, drugs, power, and vice: the latest from O...     Hulu

# %% [markdown]
# Ahora, buscamos y llenamos la informacion que tenemos de otras plataformas o de la misma pelicula en otro idioma
#
# Encontramos las peliculas/ series que estan repetidas, teniendo el mismo titulo o la misma descripción. La descripcion porque algunos titulos son diferentes - EJ: Coco y Coco(In Spanish)- pero que, por la descripcion, podemos saber que es la misma pelicula/serie.

# %%
# Encontramos los repetidos de titulo y descripcion
duplicates = pd.concat([df[df.title.duplicated(keep = False)], df[df.description.duplicated(keep = False)]])

# Quitamos duplicados, los que tenian tanto duplicado de nombre como descripción
duplicates.drop_duplicates(inplace=True)

# Tomamos todas las columnas
columns = duplicates.columns

columns = columns.drop(labels= ['date_added', 'type', 'title','platform'] ) # Quitamos sobre las cuales no podemos obtener información de otro lado

empties = duplicates.isnull() # Tenemos en cuenta solo las filas que tienen nulos, es decir, que les falta información

#Recorremos los valores duplicados, manteniendo el indice original
for ind in duplicates.index: # Recorremos filas por indica
    
    for col in columns: # recorremos las columnas
        
        if (empties.loc[ind, col]): # Encontramos si el valor  especifico es nulo y queremos buscar mas informacion para remplazar
    
            # Encontramos las otras filas que tienen el mismo titulo y son del mismo tipo. Esto ultimo para asegurar que son la misma 
            # Serie/Pelicula y no una serie que se llama igual a la pelicula y viceversa
            row1 = duplicates.mask(((duplicates['title'] == duplicates['title'][ind]) & (duplicates['type'] == duplicates['type'][ind])) & (duplicates.index != ind))
            # Encontramos las otras filas que tienen la misma descripcion y tambien son del mismo tipo
            row2 = duplicates[(duplicates['description'] == duplicates['description'][ind]) & (duplicates['type'] == duplicates['type'][ind]) & (duplicates.index != ind)]
            
            rows = pd.concat([row1, row2]) # Concatenamos ambos dataframes para usarlos como uno solo
            rows.drop_duplicates(inplace = True) # removemos duplicados exactos para recorrer menos filas
            
            for i in rows.index: # Recorremos el subset de los duplicados de la fila en cuestion
                if(rows.isnull().loc[i, col] == False): # buscamos en solo la columna en cuestion
                    # Si encontramos el valor no nulo de una columna, remplazamos el nulo por ese
                    df.loc[ind,col] = rows.loc[i, col]
                    break #Como solo tenemos una fila especifica y una columna especifica, una vez se remplaza, no necesita seguir buscando mas
                
# al final debemos tener toda la informacion que tenemos de todos los duplicados, ya aplicada

# %% [markdown]
# Revisamos el impacto que logramos

# %%
df.info()
df.nunique()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22998 entries, 0 to 22997
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          22998 non-null  object
#  1   title         22998 non-null  object
#  2   director      15712 non-null  object
#  3   cast          18317 non-null  object
#  4   country       12637 non-null  object
#  5   date_added    13444 non-null  object
#  6   release_year  22998 non-null  int64
#  7   rating        21961 non-null  object
#  8   duration      22769 non-null  object
#  9   listed_in     22998 non-null  object
#  10  description   22998 non-null  object
#  11  platform      22998 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 2.1+ MB
# type                2
# title           22115
# director        10106
# cast            16748
# country           886
# date_added       2058
# release_year      101
# rating             27
# duration          253
# listed_in        1687
# description     22670
# platform            4
# dtype: int64
#       type                                             title  \
# 0    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1    Movie                            Ernest Saves Christmas
# 2    Movie                      Ice Age: A Mammoth Christmas
# 3    Movie                        The Queen Family Singalong
# 4  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# 3  Darren Criss, Adam Lambert, Derek Hough, Alexa...            NaN
# 4  John Lennon, Paul McCartney, George Harrison, ...            NaN
#
#           date_added  release_year rating  duration  \
# 0  November 26, 2021          2016   TV-G    23 min
# 1  November 26, 2021          1988     PG    91 min
# 2  November 26, 2021          2011   TV-G    23 min
# 3  November 26, 2021          2021  TV-PG    41 min
# 4  November 25, 2021          2021    NaN  1 Season
#
#                        listed_in  \
# 0              Animation, Family
# 1                         Comedy
# 2      Animation, Comedy, Family
# 3                        Musical
# 4  Docuseries, Historical, Music
#
#                                          description platform
# 0   Join Mickey and the gang as they duck the halls!   Disney
# 1  Santa Claus passes his magic bag to a new St. ...   Disney
# 2          Sid the Sloth is on Santa's naughty list.   Disney
# 3               This is real life, not just fantasy!   Disney
# 4  A three-part documentary from Peter Jackson ca...   Disney

# %% [markdown]
# Ahora queremos una tabla de los actores que hacen parte de los show y peliculas, y una tabla que nos relaciona los actores con los shows y peliculas en los que aparecen (junction table). Esta celda demora unos 30 minutos en completarse en mi computador

# %%
# Creamos listas que despues convertiremos en dataframes
actors = []
junctionActors = []
nules = df['cast'].isnull()
# Recorremos todas las filas de el dataframe conbinado
for ind in df.index:
          # Creamos una lista de los actores desde la columna cast, separando por comas, para cada show o pelicula
    lista = str(df['cast'][ind]).split(",")
   
    # Consideramos si la lista esta vacia
    if(len(lista)>1):
    
        for actor in lista:# Recorremos esta lista de actores del show o pelicula especifico
            # Vamos a usar un algorimo de comparacion de palabras por la distancia de levenshtein.
            # En este caso se va a comparar la lista de actores que se va creando con los que vamos verificando y determinando
            # que probabilidad hay que sea el mismo que ya esta en la lista
            res = process.extractOne(actor, actors, scorer=fuzz.token_ratio, score_cutoff= 98)
            #comparamos con el resto de la lista de actores, con dos metodos y tomando el mejor. 
            # Para mas informacion visite https://maxbachmann.github.io/RapidFuzz/Usage/fuzz.html
            score = 0 # Inicializamos el score
            if(res!=None):
                cat, score, pos = res #desempacamos la tupla, si se encontraron valores
                print(actor, cat, score, pos) # imprimimos cada comparación, por si queremos hacer verificaciones a mano
            if(score > 98): #
                # si el actor ya esta en la lista de actores, solo agregamos la relacion a junction table
                junctionActors.append({'idShow': ind, 'idActor': actor.index(actor)}) #pos
            else:
                # Si no esta en la lista, lo agregamos y agregamos la relacion en la junction table
                actors.append(actor)
                junctionActors.append({'idShow': ind, 'idActor': len(actors)-1})

# No hay problema en reducir esta lista pues el usuario no va a introducir el nombre del actor, sino que dados otros parametros
# el resultado será el nombre del autor. 
# Note que la junction table usa como primary key de los actores, el indice que tiene en la tabla de actores.
# En total este metodo reduce la lista de actores en unos 4000 valores, frente a una comparacion directa

#Vemos la lista de actores
display(actors)
# Out:
#  Idina Menzel  Idina Menzel 100.0 78
#  Russi Taylor  Russi Taylor 100.0 4
# Pete Docter  Pete Docter 100.0 49
#  Jack Dylan Grazer Jack Dylan Grazer 100.0 61
#  Kari Wahlgren  Kari Wahlgren 100.0 109
#  Tress MacNeille  Tress MacNeille 100.0 2
# Larry the Cable Guy  Larry the Cable Guy 100.0 110
#  Mike Dopud  Mike Dopud 100.0 175
#  Diedrich Bader  Diedrich Bader 100.0 179
#  Bill Farmer  Bill Farmer 100.0 3
#  Will Ryan  Will Ryan 100.0 94
#  Bill Farmer  Bill Farmer 100.0 3
#  Tress MacNeille  Tress MacNeille 100.0 2
# Dave Goelz  Dave Goelz 100.0 44
#  Bill Barretta  Bill Barretta 100.0 45
#  Darren Criss Darren Criss 100.0 13
# Jason Lee Jason Lee 100.0 144
#  David Cross  David Cross 100.0 145
#  Justin Long  Justin Long 100.0 147
#  Matthew Gray Gubler  Matthew Gray Gubler 100.0 148
# Jason Lee Jason Lee 100.0 144
#  Dana Snyder  Dana Snyder 100.0 265
#  Tony Hale  Tony Hale 100.0 268
# Chris Diamantopoulos Chris Diamantopoulos 100.0 0
#  Tony Anselmo  Tony Anselmo 100.0 1
#  Tress MacNeille  Tress MacNeille 100.0 2
#  Bill Farmer  Bill Farmer 100.0 3
#  Russi Taylor  Russi Taylor 100.0 4
# Dan Castellaneta Dan Castellaneta 100.0 140
#  Nancy Cartwright  Nancy Cartwright 100.0 141
#  Yeardley Smith  Yeardley Smith 100.0 142
#  Hank Azaria  Hank Azaria 100.0 143
#  Diedrich Bader  Diedrich Bader 100.0 179
#  Ameko Eks Mass Carroll  Ameko Eks Mass Carroll 100.0 186
# Raven-Symoné  Raven-Symoné 100.0 234
#  Issac Ryan Brown Issac Ryan Brown 100.0 289
# Billie Eilish Billie Eilish 100.0 130
#  FINNEAS  FINNEAS 100.0 131
# James McAvoy James McAvoy 100.0 188
#  Michael Fassbender  Michael Fassbender 100.0 189
#  Jennifer Lawrence  Jennifer Lawrence 100.0 191
#  Nicholas Hoult  Nicholas Hoult 100.0 193
#  Emily Blunt  Emily Blunt 100.0 103
#  Dara Reneé  Dara Reneé 100.0 290
# Ben Kingsley  Ben Kingsley 100.0 118
# Jason Lee Jason Lee 100.0 144
#  Amy Adams Amy Adams 100.0 74
#  James Marsden  James Marsden 100.0 76
#  Yvette Nicole Brown  Yvette Nicole Brown 100.0 241
# Bill Farmer  Bill Farmer 100.0 3
#  Corey Burton  Corey Burton 100.0 5
# George Lopez George Lopez 100.0 441
#  Ernie Hudson  Ernie Hudson 100.0 444
#  Miguel Ferrer  Miguel Ferrer 100.0 443
#  Bill Farmer  Bill Farmer 100.0 3
#  Christian Simon  Christian J. Simon 100.0 249
# Bret Iwan Bret Iwan 100.0 235
#  Kaitlyn Robrock  Kaitlyn Robrock 100.0 236
#  Bill Farmer  Bill Farmer 100.0 3
#  Tony Anselmo  Tony Anselmo 100.0 1
#  Tress MacNeille  Tress MacNeille 100.0 2
# Tress MacNeille  Tress MacNeille 100.0 2
#  Kaitlyn Robrock  Kaitlyn Robrock 100.0 236
#  John Leguizamo  John Leguizamo 100.0 10
#  Denis Leary  Denis Leary 100.0 11
#  Queen Latifah  Queen Latifah 100.0 12
# John Leguizamo  John Leguizamo 100.0 10
#  Justin Long  Justin Long 100.0 147
#  Issac Brown Issac Ryan Brown 100.0 289
#  Melanie Minichino  Melanie Minichino 100.0 316
# Justin Felbinger Justin Felbinger 100.0 194
#  Issac Ryan Brown Issac Ryan Brown 100.0 289
#  Dee Bradley Baker  Dee Bradley Baker 100.0 315
# Josh Peck  Josh Peck 100.0 472
# Raymond Albert Romano Raymond Albert Romano 100.0 9
#  John Leguizamo  John Leguizamo 100.0 10
#  Denis Leary  Denis Leary 100.0 11
#  Queen Latifah  Queen Latifah 100.0 12
#  Scarlett Johansson Scarlett Johansson 100.0 254
#  Elle Fanning  Elle Fanning 100.0 279
#  Maria Bello  Maria Bello 100.0 198
# Cristina 'Vee" Valenzuela Cristina Vee 100.0 339
#  Bryce Papenbrook  Bryce Papenbrook 100.0 340
#  Keith Silverstein  Keith Silverstein 100.0 341
#  Carrie Keranen  Carrie Keranen 100.0 344
#  Max Mittelman  Max Mittelman 100.0 343
# Bret Iwan Bret Iwan 100.0 235
#  Russi Taylor  Russi Taylor 100.0 4
#  Bill Farmer  Bill Farmer 100.0 3
#  Daniel Ross  Daniel Ross 100.0 237
#  John Goodman  John Goodman 100.0 320
# Dan Castellaneta Dan Castellaneta 100.0 140
#  Nancy Cartwright  Nancy Cartwright 100.0 141
#  Yeardley Smith  Yeardley Smith 100.0 142
# Raven-Symoné   Raven-Symoné 100.0 234
#  Issac Brown Issac Ryan Brown 100.0 289
#  Navia Robinson  Navia Robinson 100.0 345
#  Jason Maybaum  Jason Maybaum 100.0 346
#  Sky Katz  Sky Katz 100.0 347
#  Anneliese van der Pol  Anneliese van der Pol 100.0 348
# Tony Hale  Tony Hale 100.0 268
# Ramon Reed  Ramon Reed 100.0 231
#  Kaylin Hayman  Kaylin Hayman 100.0 232
#  Suzi Barrett  Suzi Barrett 100.0 230
#  Tobie Windham Tobie Windham 100.0 229
#  Jack Dylan Grazer Jack Dylan Grazer 100.0 61
#  Marco Barricelli  Marco Barricelli 100.0 62
#  Sam Lavagnino  Sam Lavagnino 100.0 491
#  Lauren Graham  Lauren Graham 100.0 284
#  Dee Baker  Dee Bradley Baker 100.0 315
#  Jessica DiCicco  Jessica DiCicco 100.0 563
#  Awkwafina   Awkwafina 100.0 114
# Ruth Righi  Ruth Righi 100.0 399
#  Christian Simon  Christian J. Simon 100.0 249
#  Mae Whitman  Mae Whitman 100.0 487
#  Raven-Symoné   Raven-Symoné 100.0 234
#  Megan Hilty  Megan Hilty 100.0 466
# Sean Astin Sean Astin 100.0 656
#  Meghan Strange  Meghan Strange 100.0 657
#  Amber Hood  Amber Hood 100.0 659
#  Phill Lewis  Phill Lewis 100.0 658
# Hugh Jackman  Hugh Jackman 100.0 428
#  Halle Berry  Halle Berry 100.0 430
#  Ian McKellen  Ian McKellen 100.0 429
#  Famke Janssen  Famke Janssen 100.0 431
# Ioan Gruffudd Ioan Gruffudd 100.0 421
#  Jessica Alba  Jessica Alba 100.0 422
#  Chris Evans  Chris Evans 100.0 423
#  Michael Chiklis  Michael Chiklis 100.0 424
#  Julian McMahon  Julian McMahon 100.0 425
#  Kerry Washington  Kerry Washington 100.0 426
#  April Winchell  April Winchell 100.0 375
#  Tom Kenny  Tom Kenny 100.0 449
#  Tony Anselmo  Tony Anselmo 100.0 1
# Lin-Manuel Miranda  Lin-Manuel Miranda 100.0 935
# Hugh Jackman  Hugh Jackman 100.0 428
#  James McAvoy James McAvoy 100.0 188
#  Michael Fassbender  Michael Fassbender 100.0 189
#  Jennifer Lawrence  Jennifer Lawrence 100.0 191
#  Halle Berry  Halle Berry 100.0 430
#  Nicholas Hoult  Nicholas Hoult 100.0 193
# Lin-Manuel Miranda  Lin-Manuel Miranda 100.0 935
#  Thomas Kail  Thomas Kail 100.0 1276
#  Renee Goldsberry  Renee Goldsberry 100.0 1280
#  Leslie Odom Jr.  Leslie Odom Jr. 100.0 1278
#  Daveed Diggs  Daveed Diggs 100.0 976
#  Phillipa Soo  Phillipa Soo 100.0 1279
# Daveed Diggs  Daveed Diggs 100.0 976
#  Jonathan Groff  Jonathan Groff 100.0 87
#  Christopher Jackson  Christopher Jackson 100.0 1277
#  Lin-Manuel Miranda  Lin-Manuel Miranda 100.0 935
# Ray Romano Ray Romano 100.0 470
#  John Leguizamo  John Leguizamo 100.0 10
#  Denis Leary  Denis Leary 100.0 11
#  Adam Devine Adam DeVine 100.0 1216
# Dwayne Johnson Dwayne Johnson 100.0 102
#  Carla Gugino  Carla Gugino 100.0 787
#  Tom Scott  Tom Scott 100.0 1110
#  Chauncey Leopardi  Chauncey Leopardi 100.0 525
#  Patrick Renna  Patrick Renna 100.0 524
# Emilio Estevez Emilio Estevez 100.0 1181
#  Heidi Kling  Heidi Kling 100.0 1189
#  Joshua Jackson  Joshua Jackson 100.0 1185
# Kristen Bell Kristen Bell 100.0 86
#  Idina Menzel  Idina Menzel 100.0 78
#  Josh Gad  Josh Gad 100.0 88
#  Jonathan Groff  Jonathan Groff 100.0 87
# Walt Disney Walt Disney 100.0 91
# Walt Disney Walt Disney 100.0 91
#  Dr. Wernher von Braun  Dr. Wernher von Braun 100.0 1323
#  Chris Evans  Chris Evans 100.0 423
#  Scarlett Johansson Scarlett Johansson 100.0 254
#  Alex Linz Alex D. Linz 100.0 968
#  Brad Garrett  Brad Garrett 100.0 660
#  Ron Perlman  Ron Perlman 100.0 895
#  Glenn Close  Glenn Close 100.0 1333
# Jeff Bennett  Jeff Bennett 100.0 857
#  Jim Cummings  Jim Cummings 100.0 238
#  Tress MacNeille  Tress MacNeille 100.0 2
# Bill Murray  Bill Murray 100.0 459
#  Ben Kingsley  Ben Kingsley 100.0 118
#  Scarlett Johansson Scarlett Johansson 100.0 254
# Mae Whitman  Mae Whitman 100.0 487
#  Lucy Liu  Lucy Liu 100.0 649
#  Raven-Symoné   Raven-Symoné 100.0 234
#  Megan Hilty  Megan Hilty 100.0 466
#  April Winchell  April Winchell 100.0 375
#  Corey Burton  Corey Burton 100.0 5
#  Frank Welker  Frank Welker 100.0 1121
# Charles Fleischer Charles Fleischer 100.0 1347
#  April Winchell  April Winchell 100.0 375
#  Lou Hirsch  Lou Hirsch 100.0 1349
#  Corey Burton  Corey Burton 100.0 5
#  Kathleen Turner  Kathleen Turner 100.0 1348
#  Jake Short  Jake Short 100.0 1314
# Tony Hale  Tony Hale 100.0 268
#  Bob Peterson Bob Peterson 100.0 381
#  Tom Kenny  Tom Kenny 100.0 449
# Larry the Cable Guy   Larry the Cable Guy 100.0 110
#  Keith Ferguson  Keith Ferguson 100.0 671
# Larry the Cable Guy   Larry the Cable Guy 100.0 110
#  Keith Ferguson  Keith Ferguson 100.0 671
# Larry the Cable Guy   Larry the Cable Guy 100.0 110
#  Keith Ferguson  Keith Ferguson 100.0 671
#  Bob Peterson Bob Peterson 100.0 381
# Keith Ferguson  Keith Ferguson 100.0 671
# Larry the Cable Guy   Larry the Cable Guy 100.0 110
#  Keith Ferguson  Keith Ferguson 100.0 671
#  John Higgins  John Higgins 100.0 1061
# Larry the Cable Guy   Larry the Cable Guy 100.0 110
#  Keith Ferguson  Keith Ferguson 100.0 671
#  Michael Wallis  Michael Wallis 100.0 1662
# Larry the Cable Guy   Larry the Cable Guy 100.0 110
#  Keith Ferguson  Keith Ferguson 100.0 671
#  Josh Cooley  Josh Cooley 100.0 1655
#  Doug Doug  Doug Brochu 100.0 504
# Sigourney Weaver Sigourney Weaver 100.0 713
#  Jon Voight  Jon Voight 100.0 1434
# Dee Baker  Dee Bradley Baker 100.0 315
#  Dove Cameron Dove Cameron 100.0 323
#  Skai Jackson  Skai Jackson 100.0 1564
#  Kathreen Khavari  Kathreen Khavari 100.0 1565
# Miley Cyrus Miley Cyrus 100.0 1501
# Tommy Davidson  Tommy Davidson 100.0 136
#  Paula Parker  Paula Jai Parker 100.0 137
#  Kyla Pratt Kyla Pratt 100.0 135
#  Tara Strong  Tara Strong 100.0 565
# Grey DeLisle  Grey DeLisle 100.0 795
#  Mark Hamill  Mark Hamill 100.0 51
#  Tom Kenny  Tom Kenny 100.0 449
# Tony Hale  Tony Hale 100.0 268
#  Bob Peterson Bob Peterson 100.0 381
# Mark Hamill  Mark Hamill 100.0 51
#  Carrie Fisher Carrie Fisher 100.0 1403
#  Adam Driver  Adam Driver 100.0 1404
#  Daisy Ridley  Daisy Ridley 100.0 1405
#  John Boyega  John Boyega 100.0 1406
#  Oscar Isaac  Oscar Isaac 100.0 1238
# Tony Hale  Tony Hale 100.0 268
#  Bonnie Hunt  Bonnie Hunt 100.0 883
#  Bob Peterson Bob Peterson 100.0 381
# Thomas Church  Thomas Haden Church 100.0 498
# Joshua Bassett  Joshua Bassett 100.0 985
#  Olivia Rodrigo Olivia Rodrigo 100.0 984
#  Sofia Wylie  Sofia Wylie 100.0 986
#  Matt Cornett  Matt Cornett 100.0 987
# Raymond Albert Romano Raymond Albert Romano 100.0 9
#  John Leguizamo  John Leguizamo 100.0 10
#  Denis Leary  Denis Leary 100.0 11
#  Queen Latifah  Queen Latifah 100.0 12
# Willem Dafoe  Willem Dafoe 100.0 311
# Tony Hale  Tony Hale 100.0 268
#  Kristen Schaal  Kristen Schaal 100.0 539
#  Bob Peterson Bob Peterson 100.0 381
# Tony Hale  Tony Hale 100.0 268
#  Betty White Betty White 100.0 161
#  Kristen Schaal  Kristen Schaal 100.0 539
# Chris Hemsworth  Chris Hemsworth 100.0 1328
#  Tom Hiddleston  Tom Hiddleston 100.0 1346
#  Idris Elba  Idris Elba 100.0 1342
#  Jeff Goldblum  Jeff Goldblum 100.0 934
# Max Charles  Max Charles 100.0 303
#  Atticus Shaffer  Atticus Shaffer 100.0 1488
# Allison Janney  Allison Janney 100.0 849
#  Jon Voight  Jon Voight 100.0 1434
# Lara Miller  Lara Jill Miller 100.0 840
#  Tom Kenny  Tom Kenny 100.0 449
#  Kari Wahlgren  Kari Wahlgren 100.0 109
#  Dr. Pol  Dr. Pol 100.0 378
# Dee Baker  Dee Bradley Baker 100.0 315
#  Dove Cameron Dove Cameron 100.0 323
#  Skai Jackson  Skai Jackson 100.0 1564
#  Kathreen Khavari  Kathreen Khavari 100.0 1565
#  Kamil McFadden  Kamil McFadden 100.0 1693
# Dee Baker  Dee Bradley Baker 100.0 315
#  Chloe Bennet  Chloe Bennet 100.0 1740
#  Dove Cameron Dove Cameron 100.0 323
#  Kathreen Khavari  Kathreen Khavari 100.0 1565
#  Daisy Lightfoot  Daisy Lightfoot 100.0 1566
#  Fiona Bishop  Fiona Bishop 100.0 489
#  Dee Baker  Dee Bradley Baker 100.0 315
#  Tom Kenny  Tom Kenny 100.0 449
# Mandy Moore Mandy Moore 100.0 125
# Ari Rubin Ari Rubin 100.0 1739
#  Dr. Pol  Dr. Pol 100.0 378
#  Benjamin Bratt Benjamin Bratt 100.0 1446
#  Alanna Ubach  Alanna Ubach 100.0 1450
#  Jaime Camil  Jaime Camil 100.0 1451
# Anthony Gonzalez Anthony Gonzalez 100.0 1745
#  Gael García Bernal  Gael Bernal 100.0 1746
#  Benjamin Bratt Benjamin Bratt 100.0 1446
#  Alanna Ubach  Alanna Ubach 100.0 1450
#  Renée Victor  Renée Victor 100.0 1747
#  Jaime Camil  Jaime Camil 100.0 1451
# Tony Hale  Tony Hale 100.0 268
#  Wallace Shawn  Wallace Shawn 100.0 958
#  Bob Peterson Bob Peterson 100.0 381
#  Queen Latifah  Queen Latifah 100.0 12
#  John Stamos John Stamos 100.0 716
# Tony Hale  Tony Hale 100.0 268
#  Robin Downes  Robin Downes 100.0 1572
#  Bob Peterson Bob Peterson 100.0 381
# Bret Iwan Bret Iwan 100.0 235
#  Russi Taylor  Russi Taylor 100.0 4
#  Bill Farmer  Bill Farmer 100.0 3
#  Daniel Ross  Daniel Ross 100.0 237
#  Tress MacNeille  Tress MacNeille 100.0 2
# Tony Hale  Tony Hale 100.0 268
#  Bob Peterson Bob Peterson 100.0 381
#  Martin Short  Martin Short 100.0 1485
# Glenn Close  Glenn Close 100.0 1333
#  Ioan Gruffudd Ioan Gruffudd 100.0 421
# Dave Foley  Dave Foley 100.0 162
#  Julia Louis-Dreyfus  Julia Louis-Dreyfus 100.0 1056
# Bill Farmer  Bill Farmer 100.0 3
#  Jim Cummings  Jim Cummings 100.0 238
#  Wallace Shawn  Wallace Shawn 100.0 958
# Thomas Nicholas Thomas Ian Nicholas 100.0 203
#  Joss Ackland  Joss Ackland 100.0 1303
#  Stan Lee  Stan Lee 100.0 1688
# Ellen DeGeneres Ellen DeGeneres 100.0 920
# Albert Brooks  Albert Brooks 100.0 2228
#  Ellen DeGeneres Ellen DeGeneres 100.0 920
#  Alexander Gould  Alexander Gould 100.0 1879
#  Willem Dafoe  Willem Dafoe 100.0 311
#  Brad Garrett  Brad Garrett 100.0 660
#  Allison Janney  Allison Janney 100.0 849
# Sinbad   Sinbad 100.0 151
#  Art Fleur Art La Fleur 100.0 521
# Eli Fucile  Eli Fucile 100.0 1250
# Robin Williams Robin Williams 100.0 450
#  Raymond Barry  Raymond Barry 100.0 1671
#  Clancy Brown  Clancy Brown 100.0 1117
# Raymond Albert Romano Raymond Albert Romano 100.0 9
#  John Leguizamo  John Leguizamo 100.0 10
#  Denis Leary  Denis Leary 100.0 11
#  Queen Latifah  Queen Latifah 100.0 12
# Tony Hale  Tony Hale 100.0 268
#  John Ratzenberger  John Ratzenberger 100.0 1753
#  Bob Peterson Bob Peterson 100.0 381
# Frank Thomas  Frank Thomas 100.0 58
#  Daniel Stern  Daniel Stern 100.0 1068
# Jamie Curtis  Jamie Lee Curtis 100.0 913
#  Lindsay Lohan Lindsay Lohan 100.0 2024
#  Stephen Tobolowsky  Stephen Tobolowsky 100.0 458
#  Christina Vidal  Christina Vidal 100.0 1932
# Zendaya   Zendaya  100.0 1230
#  Bella Thorne  Bella Thorne 100.0 271
#  Stefanie Scott  Stefanie Scott 100.0 1315
# Kristen Bell Kristen Bell 100.0 86
#  Idina Menzel  Idina Menzel 100.0 78
#  Jonathan Groff  Jonathan Groff 100.0 87
#  Josh Gad  Josh Gad 100.0 88
#  Santino Fontana  Santino Fontana 100.0 89
#  Alan Tudyk  Alan Tudyk 100.0 992
# Alex Linz Alex D. Linz 100.0 968
#  R.H. Thomson  R.H. Thomson 100.0 755
#  John Vernon  John Vernon 100.0 666
#  Edward Asner  Edward Asner 100.0 679
#  Jeff Bennett  Jeff Bennett 100.0 857
# Sarah Hyland  Sarah Hyland 100.0 1239
#  Charles Fleischer Charles Fleischer 100.0 1347
#  Steve Purcell  Steve Purcell 100.0 1989
#  Peter Sohn  Peter Sohn 100.0 1657
#  Bob Peterson Bob Peterson 100.0 381
# Lindsay Lohan Lindsay Lohan 100.0 2024
#  Brenda Song  Brenda Song 100.0 196
#  Ben Savage Ben Savage 100.0 1914
#  Sabrina Carpenter  Sabrina Carpenter 100.0 1107
#  Leigh-Allyn Baker  Leigh-Allyn Baker 100.0 2077
#  Bradley Perry Bradley Perry 100.0 1351
# Bridgit Mendler Bridgit Mendler 100.0 2312
#  Leigh-Allyn Baker  Leigh-Allyn Baker 100.0 2077
#  Bradley Perry Bradley Perry 100.0 1351
#  Mia Talerico  Mia Talerico 100.0 2313
# Nancy Cartwright  Nancy Cartwright 100.0 141
#  Jim Cummings  Jim Cummings 100.0 238
#  Corey Burton  Corey Burton 100.0 5
#  Bill Farmer  Bill Farmer 100.0 3
#  Laurence Naismith  Laurence Naismith 100.0 814
# Edward Asner  Edward Asner 100.0 679
#  Robert Downey Jr. Robert Downey Jr. 100.0 1327
#  Scarlett Johansson Scarlett Johansson 100.0 254
#  Sebastian Stan  Sebastian Stan 100.0 835
#  Anthony Mackie Anthony Mackie 100.0 834
#  Don Cheadle  Don Cheadle 100.0 1330
# Chris Evans  Chris Evans 100.0 423
#  Hayley Atwell  Hayley Atwell 100.0 1176
#  Sebastian Stan  Sebastian Stan 100.0 835
# Chris Evans  Chris Evans 100.0 423
#  Scarlett Johansson Scarlett Johansson 100.0 254
#  Sebastian Stan  Sebastian Stan 100.0 835
#  Anthony Mackie Anthony Mackie 100.0 834
#  Samuel Jackson  Samuel L. Jackson 100.0 846
#  Chiwetel Ejiofor  Chiwetel Ejiofor 100.0 1400
#  Benedict Wong  Benedict Wong 100.0 591
#  Benjamin Bratt Benjamin Bratt 100.0 1446
# Chris Pratt  Chris Pratt 100.0 1462
#  Zoë Saldana  Zoë Saldana 100.0 1870
#  Vin Diesel Vin Diesel 100.0 578
#  Lee Pace  Lee Pace 100.0 2589
# Chris Pratt  Chris Pratt 100.0 1462
#  Bradley Cooper  Bradley Cooper 100.0 2595
#  Vin Diesel Vin Diesel 100.0 578
#  Zoë Saldana  Zoë Saldana 100.0 1870
#  Dave Bautista  Dave Bautista 100.0 2594
# Robert Downey Jr. Robert Downey Jr. 100.0 1327
#  Terrence Howard Terrence Howard 100.0 592
# Robert Downey Jr. Robert Downey Jr. 100.0 1327
#  Gwyneth Paltrow  Gwyneth Paltrow 100.0 2598
#  Don Cheadle  Don Cheadle 100.0 1330
# ...
#  ' Santino Marella',
#  ' Kennedi Clements',
#  ' Kirsten Robek',
#  ' Rachel Hayward',
#  'Betty White',
#  ' Dave Foley',
#  ' Derek Richardson',
#  ' Sarah Chalke',
#  ' W. Morgan Sheppard',
#  'Christopher Lloyd',
#  ' Danny Woodburn',
#  ' Craig Anton',
#  ' Michael Teigen',
#  ' Ben Giroux',
#  ' Paul Rae',
#  'Dominic Scott Kay',
#  ' John Kapelos',
#  ' Lise Simms',
#  ' Mike Dopud',
#  ' Charles C. Stevenson Jr.',
#  ' Dylan Minnette',
#  'F.T. Anderson',
#  ' Diedrich Bader',
#  ' Field Cate',
#  ' Kendall Cross',
#  ' Mark Downey',
#  'Resse Alexander',
#  ' Sahar Biniaz',
#  ' Jan Boss',
#  ' Ameko Eks Mass Carroll',
#  ' Melody Choi',
#  'James McAvoy',
#  ' Michael Fassbender',
#  ' Rose Byrne',
#  ' Jennifer Lawrence',
#  ' January Jones',
#  ' Nicholas Hoult',
#  'Justin Felbinger',
#  ' Amanda Leighton',
#  ' Brenda Song',
#  'Kevin Costner',
#  ' Maria Bello',
#  ' Morgan Saylor',
#  ' Martha Higareda',
#  ' Michael Aguero',
#  ' Sergio Avelar',
#  'Thomas Ian Nicholas',
#  ' Gary Busey',
#  ' Albert Hall',
#  ' Amy Morton',
#  ' Dan Hedaya',
#  ' Eddie Bracken',
#  'Gino Conforti',
#  ' Barbara Cook',
#  ' Jodi Benson',
#  ' June Foray',
#  ' Kenneth Mars',
#  'Kyle Breitkopf',
#  ' Jacob Ursomarzo',
#  ' Addison Holley',
#  'Bill Anders',
#  ' Jack Clemons',
#  ' Fred Haise',
#  ' Glynn Lunney',
#  ' Jay Barbree',
#  ' Brad Vinikow',
#  'Mckenna Grace',
#  ' Lexi Underwood',
#  ' Cedric Joe',
#  ' Tim Heidecker',
#  ' Riki Lindhome',
#  ' Nasim Pedrad',
#  'Tobie Windham',
#  ' Suzi Barrett',
#  ' Ramon Reed',
#  ' Kaylin Hayman',
#  ' JC Currais',
#  ' Raven-Symoné',
#  'Bret Iwan',
#  ' Kaitlyn Robrock',
#  ' Daniel Ross',
#  ' Jim Cummings',
#  ' Will Arnett',
#  ' Taraji P. Henson',
#  ' Yvette Nicole Brown',
#  'Whoopi Goldberg',
#  ' Christina Aguilera',
#  ' Halle Bailey',
#  ' Orlando Philharmonic Orchestra',
#  ' Anthony Anderson',
#  ' Tom Brady',
#  'Malachi Barton',
#  ' Christian J. Simon',
#  ' Sophia Hammons',
#  ' Melanie Brook',
#  ' Brent Stait',
#  ' Jordana Largy',
#  'Scarlett Johansson',
#  ' Florence Pugh',
#  ' David Harbour',
#  ' O-T Fagbenle',
#  ' Rachel Weisz',
#  ' Ray Winstone',
#  'Dr. Anthony Fauci',
#  ' Bono',
#  ' George W. Bush',
#  ' Peter Staley',
#  'Ashly Burch',
#  ' Dana Snyder',
#  ' Cameron Richardson',
#  ' Jane Lynch',
#  ' Tony Hale',
#  ' Kimberly Williams-Paisley',
#  ' Josh Green',
#  ' Bella Thorne',
#  ' Uzo Aduba',
#  'Jake Green',
#  ' Raphael Alejandro',
#  ' Christian Slater',
#  ' Trevor Devall',
#  'Angelina Jolie',
#  ' Sharlto Copley',
#  ' Elle Fanning',
#  ' Sam Riley',
#  ' Imelda Staunton',
#  ' Juno Temple',
#  'Isabella Crovetti',
#  ' Lauren Graham',
#  ' James Van Der Beek',
#  ' Jordan Davis',
#  ' Wanda Sykes',
#  ' Mitchell Whitfield',
#  'Issac Ryan Brown',
#  ' Dara Reneé',
#  ' Graciela Gomez',
#  'Cole Caplan',
#  ' Kristen Bone',
#  ' Robert Smith',
#  ' Catherine Disher',
#  ' Adrian Truss',
#  ' Len Carlson',
#  ' Julie Kavner',
#  ' Pamela Hayden',
#  'Apthon Corbin',
#  ' Louis Gonzales',
#  'Tucker Albrizzi',
#  ' Max Charles',
#  ' Tim Conway',
#  ' Jennifer Elise Cox',
#  'Shailene Woodley',
#  ' Ansel Elgort',
#  ' Laura Dern',
#  ' Sam Trammell',
#  ' Nat Wolff',
#  ' Willem Dafoe',
#  'Benjamin Valic',
#  ' Lily Sanfelippo',
#  ' Jakari Fraser',
#  ' Dee Bradley Baker',
#  ' Melanie Minichino',
#  'Isla Fisher',
#  ' Hugh Dancy',
#  ' Joan Cusack',
#  ' John Goodman',
#  ' John Lithgow',
#  ' Kristin Scott Thomas',
#  'Dove Cameron',
#  ' Sofia Carson',
#  ' Booboo Stewart',
#  ' Mitchell Hope',
#  ' Sarah Jeffery',
#  ' Melanie Paxson',
#  'John Barrowman',
#  ' Ashley Brown',
#  ' Merle Dandridge',
#  ' Trevor Dion Nicholas',
#  ' Jade Ewen',
#  ' Alton Fitzgerald White',
#  'Chip Hailstone',
#  ' Agnes Hailstone',
#  ' Sue Aikens',
#  ' Andy Bassich',
#  'Cristina Vee',
#  ' Bryce Papenbrook',
#  ' Keith Silverstein',
#  ' Mela Lee',
#  ' Max Mittelman',
#  ' Carrie Keranen',
#  ' Navia Robinson',
#  ' Jason Maybaum',
#  ' Sky Katz',
#  ' Anneliese van der Pol',
#  'Johnny Depp',
#  ' Penélope Cruz',
#  ' Ian McShane',
#  ' Geoffrey Rush',
#  ' Kevin R. McNally',
#  ' Sam Claflin',
#  'Kaylin Price',
#  ' Ariana Brown',
#  ' Aliyah Taylor',
#  ' Janelle LaSalle',
#  ' Napoleon Highbrou',
#  'Peyton Elizabeth Lee',
#  ' Emma Meisel',
#  ' Matthew Sato',
#  ' Wes Tian',
#  ' Jeffrey Bowyer-Chapman',
#  ' Mapuana Makia',
#  'Leela Ladnier',
#  ' Utkarsh Ambudkar',
#  ' Roshni Edwards',
#  ' Kal Penn',
#  ' Kamran Lucas',
#  'Kathleen Wilhoite',
#  ' Clea Lewis',
#  ' Danny Cooksey',
#  ' Pamela Segall',
#  ' April Winchell',
#  ' Don Adams',
#  'Rick Robles',
#  ' Dr. Pol',
#  ' Sophie Turner',
#  ' Tye Sheridan',
#  'Bob Peterson',
#  ' Ed Asner',
#  ' Jordan Nagai',
#  'Emma Stone',
#  ' Emma Thompson',
#  ' Joel Fry',
#  ' Paul Walter Hauser',
#  ' Emily Beecham',
#  ' Kirby Howell-Baptiste',
#  'Steve Carell',
#  ' Juliette Binoche',
#  ' Dane Cook',
#  ' John Mahoney',
#  ' Alison Pill',
#  'Txunamy Oriz',
#  ' Natalie Peyser',
#  ' Frankie Rodriguez',
#  ' Julia Lester',
#  ' Ruth Righi',
#  ' Scoot McNairy',
#  ' Lester Speight',
#  ' Sam Rockwell',
#  ' Matt Gerald',
#  ' Allen Maldonado',
#  ' Jim Belushi',
#  ' Peter Dinklage',
#  ' Patrick Warburton',
#  ' Alex Neuberger',
#  'Dr. Susan Kelleher',
#  ' Art Edmonds',
#  'Dylan Schombing',
#  ' Áine Sunderland',
#  ' Nahanni Mitchell',
#  ' Nicholas Holmes',
#  'Ed Speleers',
#  ' Jeremy Irons',
#  ' Sienna Guillory',
#  ' Robert Carlyle',
#  ' John Malkovich',
#  ' Garrett Hedlund',
#  'Ioan Gruffudd',
#  ' Jessica Alba',
#  ' Chris Evans',
#  ' Michael Chiklis',
#  ' Julian McMahon',
#  ' Kerry Washington',
#  'Patrick Stewart',
#  ' Hugh Jackman',
#  ' Ian McKellen',
#  ' Halle Berry',
#  ' Famke Janssen',
#  'Ramone Hamilton',
#  ' Gabriella Graves',
#  ' Maxwell Simkins',
#  'Kylie Cantrall',
#  ' Maxwell Donovan',
#  ' Callan Farris',
#  ' Coco Christo',
#  ' Valery Ortiz',
#  ' Nathan Lovejoy',
#  'George Lopez',
#  ' Odette Yustman',
#  ' Miguel Ferrer',
#  ' Ernie Hudson',
#  ' Loretta Devine',
#  ' Jon Huertas',
#  ' Odette Annable',
#  ' Kay Panabaker',
#  ' Tom Kenny',
#  'Robin Williams',
#  ' Sally Field',
#  ' Pierce Brosnan',
#  ' Harvey Fierstein',
#  ' Polly Holliday',
#  ' Lisa Jakub',
#  'Breckin Meyer',
#  ' Jennifer Love Hewitt',
#  ' Stephen Tobolowsky',
#  ' Bill Murray',
#  ' Evan Arnold',
#  ' Mark Lawrence',
#  'Matthew Géczy',
#  ' Kaycie Chase',
#  ' Sylvain Caruso',
#  'Vanessa Williams',
#  ' Megan Hilty',
#  ' Jet Jurgensmeyer',
#  ' Harvey Guillén',
#  ' Nika Futterman',
#  'Ray Romano',
#  ' Seann William Scott',
#  ' Josh Peck',
#  'Valerie Taylor',
#  ' Dr. Sylvia Earle',
#  ' Jeremiah Sullivan',
#  ' Wendy Benchley',
#  ' Jean Michel Cousteau',
#  ' Michele Hall',
#  ' Tiya Sircar',
#  ' Skyler Stone',
#  ' Angourie Rice',
#  ' Charlie Rowe',
#  'Sarah-Nicole Robles',
#  ' Wendie Malick',
#  ' Alex Hirsch',
#  ' Tati Gabrielle',
#  ' Mae Whitman',
#  'Ben Valic',
#  ' Fiona Bishop',
#  ' Ivy Bishop',
#  ' Sam Lavagnino',
#  ' Carra Patterson',
#  ' Lyndsy Fonseca',
#  ' Vanessa Lengies',
#  ' Brandon Jay Mclaren',
#  ' Anthony Ruivivar',
#  'Matt Damon',
#  ' Thomas Haden Church',
#  ' Patrick Fugit',
#  ' Colin Ford',
#  'Tiffany Thornton',
#  ' Sterling Knight',
#  ' Brandon Mychal Smith',
#  ' Doug Brochu',
#  ' Allisyn Ashley Arm',
#  'Alison Lohman',
#  ' Tim McGraw',
#  ' Ryan Kwanten',
#  ' Danny Pino',
#  ' Dallas Roberts',
#  ' Todd Haberkorn',
#  'Kina Scollay',
#  ' Ingrid Visser',
#  ' Ray Robertson',
#  ' Tress MacNeile',
#  'Billy Crystal',
#  ' Ben Feldman',
#  ' Mindy Kaling',
#  ' Henry Winkler',
#  ' Lucas Neff',
#  'Art La Fleur',
#  ' Tom Guiry',
#  ' Mike Vitar',
#  ' Patrick Renna',
#  ' Chauncey Leopardi',
#  ' Marty York',
#  'Max Lloyd-Jones',
#  ' James Willson',
#  ' Samantha Burton',
#  ' Brett Kelly',
#  ' James Earl Jones',
#  ' Cole Evan Weiss',
#  'Elisabeth Shue',
#  ' Maia Brewton',
#  ' Keith Coogan',
#  ' Anthony Rapp',
#  ' Calvin Levels',
#  " Vincent Phillip D'Onofrio",
#  ' Kristen Schaal',
#  ' Mystic Inscho',
#  ' Seth Carr',
#  ' Marta Kessler',
#  ' Emmy DeOliveira',
#  'Tyler Nathan',
#  ' Jacob Mazeral',
#  ' Ava Ro',
#  ' Scott Gorman',
#  ' Athena Karkanis',
#  'Dr. Erin Schroeder',
#  ' Dr. Ben Schroeder',
#  'Jacob Tremblay',
#  ' Emma Berman',
#  ' Maya Rudolph',
#  ' Jim Gaffigan',
#  'Anthony Daniels',
#  ' R2-D2',
#  ' Lesleh Donaldson',
#  ' Andrew Sabiston',
#  ' Don Francks',
#  ' Dan Hennessey',
#  'Harland Williams',
#  ' Isaac Brown',
#  ' Jessica DiCicco',
#  ' Leslie Baker',
#  ' Tara Strong',
#  'Alan Cumming',
#  ' Evan Rachel Wood',
#  ' Elijah Kelley',
#  ' Meredith Anne Bull',
#  ' Sam Palladio',
#  ' Kristin Chenoweth',
#  'Fred MacMurray',
#  ' Tommy Steele',
#  ' Greer Garson',
#  ' Geraldine Page',
#  ' Gladys Cooper',
#  ' Hermione Baddeley',
#  'Vin Diesel',
#  ' Faith Ford',
#  ' Brittany Snow',
#  ' Max Thieriot',
#  ' Chris Potter',
#  'Matt Danner',
#  ' Melanie Harrison',
#  ' Ben Diskin',
#  ' Eric Bauza',
#  'Kelly Marie Tran',
#  ' Izaac Wang',
#  ' Gemma Chan',
#  ' Daniel Dae Kim',
#  ' Benedict Wong',
#  'Terrence Howard',
#  ' Cuba Gooding Jr.',
#  ' Nate Parker',
#  ' David Oyelowo',
#  ' Tristan Wilds',
#  ' Ne-Yo',
#  'Shanessa Khawaja',
#  ' Jenna Qureshi',
#  ' Cash Herrera',
#  ' Fazeelat Aslam',
#  ' Maya Bednarek',
#  ' Iris Starlett Perry',
#  'Dave Mccormack',
#  ' Melanie Zanetti',
#  ' Brad Elliot',
#  ' Hsiao-Ling Tang',
#  'Qi Sun',
#  ' Briana Liu',
#  ' Ben Wang',
#  ' Harry Jarvis',
#  ' Ray Wise',
#  ' DeJean Brown',
#  ' Ava Kolker',
#  ' Jackson Dollinger',
#  ' Ian Kesler',
#  ' Caroline Rhea',
#  'Keyla Monterroso Mejia',
#  ' Cristela Alonzo',
#  ' Grace Song',
#  ' Olivia Sullivent',
#  ' Gilberto Ortiz',
#  ' Sean Burgos',
#  'Otmara Marrero',
#  ' Dash McCloud',
#  ' Greg Worswick',
#  ' Mike Millan',
#  'Melba Martinez ph.D',
#  ' Cici Lau',
#  ' Seven True-Divine Purnell',
#  ' William Knight',
#  ' Amanda Maddock',
#  ' Ronald Binion',
#  'Kalo Moss',
#  ' Ching Yin Ryan Hu',
#  ' Evan Lai',
#  ' Brian Yang',
#  ' Lynn Chen',
#  ' Danni Wang',
#  'Chris Houghton',
#  ' Marieve Herington',
#  ' Bob Joles',
#  ' Artemis Pebdani',
#  'David Wartnaby',
#  ' Bjørn Lægreid',
#  ' Thord Paulsen',
#  'Ginnifer Goodwin',
#  ' Rosario Dawson',
#  ' Lucy Liu',
#  'Bob Dorough',
#  ' Jack Sheldon',
#  ' Lynn Ahrens',
#  ' Grady Tate',
#  ' Blossom Dearie',
#  ' Essra Mohawk',
#  'Sean Astin',
#  ' Meghan Strange',
#  ' Phill Lewis',
#  ' Amber Hood',
#  ' Brad Garrett',
#  ' Gary Anthony Williams',
#  ' Cam Clarke',
#  ' Anna Paquin',
#  ' Kelsey Grammer',
#  'Neal McDonough',
#  ' John Vernon',
#  ' Luke Perry',
#  ' Lou Ferrigno',
#  ' Genie Francis',
#  'Jack McBrayer',
#  ' Keith Ferguson',
#  'Gabrielle Anwar',
#  ' Michael Schoeffling',
#  ' Kathleen York',
#  ' Dylan Kussman',
#  ' Cliff Robertson',
#  ' Frank Renzulli',
#  'Christopher Daniel Barnes',
#  ' Edward Asner',
#  ' Linda Gray',
#  ' Rodney Saulsberry',
#  ' Liz Georges',
#  ' Saratoga Ballantine',
#  'Tina Fey',
#  ' Richard Ayoade',
#  ' Alice Braga',
#  'Patrick Richwood',
#  ' Reece Holland',
#  ' John Robert Hoffman',
#  ' Wesley Mann',
#  ' Harry Waters Jr.',
#  ' John Lovelady',
#  'Takuya Ohashi',
#  ' Shintaro Tokita',
#  'David Tennant',
#  ' Danny Pudi',
#  ' Ben Schwartz',
#  ' Bobby Moynihan',
#  ' Kate Micucci',
#  'Gordon MacRae',
#  ' Gloria Grahame',
#  ' Gene Nelson',
#  'Joe Mantegna',
#  ' Lara Flynn Boyle',
#  ' Joe Pantoliano',
#  ' Brian Haley',
#  ' Cynthia Nixon',
#  ' Fred Dalton Thompson',
#  ' Joey Bragg',
#  ' Tenzing Norgay Trainor',
#  ' Kali Rocha',
#  ' Benjamin King',
#  'Sigourney Weaver',
#  ' James Cameron',
#  ' Brian Skerry',
#  'John Stamos',
#  ' Jessalyn Gilsig',
#  ' Richard Robichaux',
#  ' Sophia Mitri Schloss',
#  ' Nell Verlaque',
#  'Anne Hathaway',
#  ' Jesse Eisenberg',
#  ' will.i.am ',
#  ' Jamie Foxx',
#  ' Tracy Morgan',
#  'Louis Ashbourne Serkis',
#  ' Tom Taylor',
#  ' Rebecca Ferguson',
#  ' Denise Gough',
#  ' Dean Chaumoo',
#  'Richard Riehle',
#  ' Mason Cook',
#  ' Adam Alexi-Malle',
#  ' Lochlyn Munro',
#  ' Mo Gallini',
#  ' Christopher Maleki',
#  'Scott Bairstow',
#  ' Charmaine Craig',
#  ' Alfred Molina',
#  ' Geoffrey Lewis',
#  ' Al Harrington',
#  'Andy Milonakis',
#  ' James Adomian',
#  ' Melanie Lynskey',
#  ' Ryan Quincy',
#  ' Neil deGrasse Tyson',
#  'Charlie Schlatter',
#  ' Matt Jones',
#  'Chevy Chase',
#  ' Farrah Fawcett',
#  ' Jonathan Taylor Thomas',
#  ' George Wendt',
#  'Jason Robards',
#  ' Talia Shire',
#  ' R.H. Thomson',
#  ' Fiona Reid',
#  ' Chris Wiggins',
#  ' Amy Stewart',
#  'Adam Beach',
#  ' Eric Schweig',
#  ' Michael Gambon',
#  ' Nathaniel Parker',
#  ' Alex Norton',
#  ' Sheldon Peters Wolfchild',
#  'Eric Walker',
#  ' Warwick Davis',
#  ' Fionnula Flanagan',
#  ' Guy Boyd',
#  ' Aubree Miller',
#  ' Daniel Frishman',
#  'Wilford Brimley',
#  ' Siân Phillips',
#  ' Carel Struycken',
#  ' Niki Botelho',
#  'Frankie Ryan Manriquez',
#  ' Taylor Masamitsu',
#  ' Liliana Mumy',
#  ' Rory Thost',
#  ' Edie McClurg',
#  'David Hartman',
#  ' Donald Sinden',
#  ' Jacques Marin',
#  ' Mako ',
#  ' David Gwillim',
#  ' Agneta Eckemyr',
#  'Ben Stiller',
#  ' Carla Gugino',
#  ' Dick Van Dyke',
#  ' Mickey Rooney',
#  ' Bill Cobbs',
#  ' Jake Cherry',
#  'Mat Lucas',
#  ' James Arnold Taylor',
#  ' Tom Kane',
#  ' Grey DeLisle',
#  ' André Sogliuzzo',
#  'Jim Henshaw',
#  ' Cree Summer Francks',
#  ' Jackie Burroughs',
#  ' George Buza',
#  ' Doug Chamberlain',
#  ' Paul Chato',
#  'Steve Martin',
#  ' Jack Black',
#  ' Owen Wilson',
#  ' Brian Dennehy',
#  ' Anjelica Huston',
#  ' Rashida Jones',
#  'Michael Rennie',
#  ' James MacArthur',
#  ' Janet Munro',
#  ' James Donald',
#  ' Herbert Lom',
#  ' Laurence Naismith',
#  'Cody Veith',
#  ' Bryce Gheisar',
#  ' Brandon Severs',
#  ' Jillian Shea Spaeder',
#  ' Matt Lucas',
#  ' Ashley Jensen',
#  ' Michael Caine',
#  'Johnny Pemberton',
#  ' Jon Heder',
#  ' Joel Trussell',
#  'Scott Adsit',
#  ' Ryan Potter',
#  ' Brooks Wheelan',
#  ' Jamie Chung',
#  ' Khary Payton',
#  ' Genesis Rodriguez',
#  'a-chan ',
#  ' KASHIYUKA ',
#  ' NOCCHi',
#  'Anthony Mackie',
#  ' Sebastian Stan',
#  ' Daniel Brühl',
#  ' Emily VanCamp',
#  ' Wyatt Russell',
#  'Laya DeLeon Hayes',
#  ' Lara Jill Miller',
#  ' Robbie Rist',
#  ' Dr Myiesha Taylor',
#  '  MD',
#  'Eva Green',
#  ' Asa Butterfield',
#  ' Samuel L. Jackson',
#  ' Judi Dench',
#  ' Rupert Everett',
#  ' Allison Janney',
#  'Alondra Toledo',
#  ' Daniela Blanco',
#  ' Henry Onyango',
#  ' Jason Hadzikostas',
#  ' Santosh Pandey',
#  ' Billy Connolly',
#  'Dante Basco',
#  ' Jeff Bennett',
#  ' Amy Bruckner',
#  ' John DiMaggio',
#  ' Charlie Finn',
#  ' Kittie',
#  'G Hannelius',
#  ' Blake Michael',
#  ' Francesca Capaldi',
#  ' Stephen Full',
#  ' Regan Burns',
#  ' Beth Littleford',
#  'Azran Bin Ahmad',
#  ' Rozita Binti Mohamed Hussain',
#  ' Shamsir Bin Mohd Shahar',
#  ' Suzana Binti Ahmad',
#  'Mitchel Musso',
#  ' Doc Shaw',
#  ' Kelsey Chow',
#  ' Ryan Ochoa',
#  ' Geno Segers',
#  'Preston Oliver',
#  ' Kyliegh Curran',
#  ' Elle Graham',
#  ' Madeleine McGraw',
#  ' Landon Gordon',
#  ' Kelly Frye',
#  ' Bonnie Hunt',
#  ' Hilary Duff',
#  ' Tom Welling',
#  ' Piper Perabo',
#  ' Eugene Levy',
#  ' Carmen Electra',
#  'Matilda Lawler',
#  ' Anna Deavere Smith',
#  ' Benjamin Evan Ainsworth',
#  'Diego Luna',
#  ' Zoe Saldana',
#  ' Channing Tatum',
#  ' Ron Perlman',
#  ' Christina Applegate',
#  ' Ice Cube',
#  'Jim Henson',
#  ' Frank Oz',
#  ' Richard Hunt',
#  ' Eren Ozker',
#  'Giles Panton',
#  ' Rebecca Shoichet',
#  ' Jesse Inocalla',
#  ' Brad Swaile',
#  ' Deven Mack',
#  ' Ian Hanlin',
#  'Brandy Norwood',
#  ' Whitney Houston',
#  ' Bernadette Peters',
#  ' Paolo Montalbán',
#  ' Victor Garber',
#  ' Jamie Lee Curtis',
#  'Izabela Rose',
#  ' Siena Agudong',
#  ' Kyle Howard',
#  ' Elie Samouhi',
#  ' Alison Fernandez',
#  ' Max Torina',
#  'Ellen DeGeneres',
#  ' Craig T. Nelson',
#  ' Holly Hunter',
#  ' Keegan-Michael Key',
#  ' Jordan Peele',
#  'Aimee Carrero',
#  ' Jenna Ortega',
#  ' Jillian Reed',
#  ' Carlos Alazraqui',
#  ' Mikey Kelley',
#  'Bryan Cranston',
#  ' Koyu Rankin',
#  ' Edward Norton',
#  ' Bob Balaban',
#  ' Jeff Goldblum',
#  ' Lin-Manuel Miranda',
#  ' Ben Whishaw',
#  ' Emily Mortimer',
#  ' Julie Walters',
#  ' Pixie Davies',
#  'Elizabeth Olsen',
#  ' Paul Bettany',
#  ' Teyonah Parris',
#  ' Kathryn Hahn',
#  ' Randall Park',
#  ' Kat Dennings',
#  'Phil Wright',
#  ' Ariel Martin',
#  ' Trevor Tordjman',
#  'Jack Gore',
#  ' Nile Diaz',
#  ' Colin H. Murphy',
#  ' Carlos Saldanha',
#  ' Jeremy Sisto',
#  'Tom Hanks',
#  ' Tim Allen',
#  ' Kevin McKidd',
#  ' Emily Hahn',
#  ' Wallace Shawn',
#  'Jim Carrey',
#  ' Seth Rogen',
#  ' Amy Poehler',
#  'Jon Favreau',
#  ' Dave Filoni',
#  ' Pedro Pascal',
#  ' Bryce Howard',
#  ' Taika Waititi',
#  ' Carl Weathers',
#  'Alex D. Linz',
#  ' Larry Miller',
#  ' Jamie Kennedy',
#  ' Zena Grey',
#  ' Nora Dunn',
#  ' Angela Bassett',
#  ' Ahmir-Khalib "Questlove" Thompson',
#  ' Phylicia Rashad',
#  ' Daveed Diggs',
#  'Meryl Streep',
#  ' James Corden',
#  ' Anna Kendrick',
#  ' Chris Pine',
#  ' Tracey Ullman',
#  ' Selah Victor',
#  ' Sabrina Weisz',
#  'Olivia Rodrigo',
#  ' Joshua Bassett',
#  ' Sofia Wylie',
#  ' Matt Cornett',
#  ' Larry Saperstein',
#  'John C. Reilly',
#  ' Sarah Silverman',
#  ' Gal Gadot',
#  ' Alan Tudyk',
#  'Jay Reeves',
#  ' Thaddeus J. Mixson',
#  ' Corinne Foxx',
#  ' Matthew Glave',
#  ' James Badge Dale',
#  ' Hunter Sansone',
#  'Meg Ryan',
#  ...]

# %% [markdown]
# Procedemos tambien con las categorias de la misma forma, tambien creando una junction table

# %%
#Creamos listas que despues convertiremos en dataframes

categories =[]
junctionCategories = []

for ind in df.index:
    #Creamos una lista de las categorias desde la columna listed_in, separando por comas
    lista = str(df['listed_in'][ind]).split(",")
    #recorremos esta lista de categorias
    for category in lista:
        category =  (category.strip()) # removemos espacios en blanco y otros problemas del nombre.
        if(category in categories):
            #si la categoria ya esta en la lista de categorias, solo agregamos la relacion a junction table
            junctionCategories.append({'idShow': ind, 'idCategory': categories.index(category) })
        else:
            # Si no esta en la lista, lo agregamos y agregamos la relacion en la junction table
            categories.append(category)
            junctionCategories.append({'idShow': ind, 'idCategory': categories.index(category) })

# dado que las categorias si las va a indicar el usuario en los request, las dejamos sin alterar ni tratar de reducir


display(categories) # visualizamos la lista
# Out:
# ['Animation',
#  'Family',
#  'Comedy',
#  'Musical',
#  'Docuseries',
#  'Historical',
#  'Music',
#  'Biographical',
#  'Documentary',
#  'Action-Adventure',
#  'Superhero',
#  'Reality',
#  'Survival',
#  'Animals & Nature',
#  'Kids',
#  'Coming of Age',
#  'Drama',
#  'Fantasy',
#  'Lifestyle',
#  'Movies',
#  'Science Fiction',
#  'Concert Film',
#  'Crime',
#  'Sports',
#  'Anthology',
#  'Medical',
#  'Variety',
#  'Spy/Espionage',
#  'Buddy',
#  'Parody',
#  'Game Show / Competition',
#  'Romance',
#  'Anime',
#  'Romantic Comedy',
#  'Thriller',
#  'Police/Cop',
#  'Talk Show',
#  'Western',
#  'Dance',
#  'Series',
#  'Mystery',
#  'Soap Opera / Melodrama',
#  'Disaster',
#  'Travel',
#  'International',
#  'Action',
#  'Suspense',
#  'Special Interest',
#  'Adventure',
#  'Horror',
#  'Talk Show and Variety',
#  'Arts',
#  'Entertainment',
#  'and Culture',
#  'TV Shows',
#  'Music Videos and Concerts',
#  'Fitness',
#  'Faith and Spirituality',
#  'Military and War',
#  'LGBTQ',
#  'Unscripted',
#  'Young Adult Audience',
#  'Arthouse',
#  'Stand Up',
#  'Cooking & Food',
#  'Documentaries',
#  'Lifestyle & Culture',
#  'News',
#  'History',
#  'Teen',
#  'Health & Wellness',
#  'Black Stories',
#  'Latino',
#  'Late Night',
#  'Sketch Comedy',
#  'Classics',
#  'LGBTQ+',
#  'Adult Animation',
#  'Sitcom',
#  'Game Shows',
#  'Cartoons',
#  'Science & Technology',
#  'International TV Shows',
#  'TV Dramas',
#  'TV Mysteries',
#  'Crime TV Shows',
#  'TV Action & Adventure',
#  'Reality TV',
#  'Romantic TV Shows',
#  'TV Comedies',
#  'TV Horror',
#  'Children & Family Movies',
#  'Dramas',
#  'Independent Movies',
#  'International Movies',
#  'British TV Shows',
#  'Comedies',
#  'Spanish-Language TV Shows',
#  'Thrillers',
#  'Romantic Movies',
#  'Music & Musicals',
#  'Horror Movies',
#  'Sci-Fi & Fantasy',
#  'TV Thrillers',
#  "Kids' TV",
#  'Action & Adventure',
#  'TV Sci-Fi & Fantasy',
#  'Classic Movies',
#  'Anime Features',
#  'Sports Movies',
#  'Anime Series',
#  'Korean TV Shows',
#  'Science & Nature TV',
#  'Teen TV Shows',
#  'Cult Movies',
#  'Faith & Spirituality',
#  'LGBTQ Movies',
#  'Stand-Up Comedy',
#  'Stand-Up Comedy & Talk Shows',
#  'Classic & Cult TV']

# %% [markdown]
# Convertimos las listas creadas en dataframes

# %%
actDF = pd.DataFrame(actors, columns=['actors'])
actJunc_DF = pd.DataFrame(junctionActors, columns = ['idShow', 'idActor'])
catDF = pd.DataFrame(categories, columns=['categories'])
catJunc_DF = pd.DataFrame(junctionCategories, columns = ['idShow', 'idCategory'])

actDF.head()
actJunc_DF.head()
catDF.head()
catJunc_DF.head()
# Out:
#                  actors
# 0  Chris Diamantopoulos
# 1          Tony Anselmo
# 2       Tress MacNeille
# 3           Bill Farmer
# 4          Russi Taylor
#    idShow  idActor
# 0       0        0
# 1       0        1
# 2       0        2
# 3       0        3
# 4       0        4
#    categories
# 0   Animation
# 1      Family
# 2      Comedy
# 3     Musical
# 4  Docuseries
#    idShow  idCategory
# 0       0           0
# 1       0           1
# 2       1           2
# 3       2           0
# 4       2           2

# %%
# Dividimos la columna de duracion en la parte numerica y el atributo de tipo
df[['duration', 'dtype']] = df['duration'].str.split(' ', expand = True)

# %%
# reorganizo el orden de las columnas. Por preferencia
df = df[['type', 'title', 'director','cast','country', 'date_added', 'release_year', 'rating', 'duration', 'dtype', 'listed_in', 'description', 'platform']]

df.head()
# Out:
#       type                                             title  \
# 0    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1    Movie                            Ernest Saves Christmas
# 2    Movie                      Ice Age: A Mammoth Christmas
# 3    Movie                        The Queen Family Singalong
# 4  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# 3  Darren Criss, Adam Lambert, Derek Hough, Alexa...            NaN
# 4  John Lennon, Paul McCartney, George Harrison, ...            NaN
#
#           date_added  release_year rating duration   dtype  \
# 0  November 26, 2021          2016   TV-G       23     min
# 1  November 26, 2021          1988     PG       91     min
# 2  November 26, 2021          2011   TV-G       23     min
# 3  November 26, 2021          2021  TV-PG       41     min
# 4  November 25, 2021          2021    NaN        1  Season
#
#                        listed_in  \
# 0              Animation, Family
# 1                         Comedy
# 2      Animation, Comedy, Family
# 3                        Musical
# 4  Docuseries, Historical, Music
#
#                                          description platform
# 0   Join Mickey and the gang as they duck the halls!   Disney
# 1  Santa Claus passes his magic bag to a new St. ...   Disney
# 2          Sid the Sloth is on Santa's naughty list.   Disney
# 3               This is real life, not just fantasy!   Disney
# 4  A three-part documentary from Peter Jackson ca...   Disney

# %% [markdown]
# Guardamos los dataframes como CSV

# %%
df.to_csv('./Exported Data/catalog.csv')
actDF.to_csv('./Exported Data/actors.csv')
actJunc_DF.to_csv('./Exported Data/actorsjunc.csv')
catDF.to_csv('./Exported Data/categories.csv')
catJunc_DF.to_csv('./Exported Data/categoriesjunc.csv')
